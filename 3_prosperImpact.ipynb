# %% [markdown]
# # PROSPERIMPACT

# %% [markdown]
# This notebook calculates the dynamic impact as additional radiative forcing and saves the results in excel files.

# %% [markdown]
# environment: premise2 (theoretically every other)

# %% [markdown]
# Calculations are possible for methane, carbon dioxide and dinitrogen oxide. The calculations follow the IPCC assessment report 5, chapter 8. The calculations for dinitrogen oxide are slihtly simplified.

# %% [markdown]
# # Impulse response functions

# %%
import math

# %%
def prospRF(measd):
    t = 0
    reCO2 = 1.37e-05 #[W/(m²ppb)] entsp. AR5 Table 8A1
    reCH4 = 3.63e-4 #[W/(m²ppb)] entsp. AR5 Table 8A1
    reN2O = 3.00e-3 #[W/(m²ppb)] entsp. AR5 Table 8A1
    mbCO2 = 1.28301e-10 #[ppb/kg] 
    mbCH4 = 3.52827e-10 #[ppb/kg] 
    mbN2O = 1.22722e-10 #[ppb/kg] 
    f1f2 = 1 + 0.5 + 0.15 #entsp. AR5 8SM
    trfCO2 = []
    for t in range(measd):
        rfCO2 = mbCO2 * reCO2 * (0.2173 + 0.224 * math.exp(-(t/394.4)) + 0.2824 * math.exp(-(t/36.54)) + 0.2763 * math.exp(-(t/4.304)))
        t = t + 1
        trfCO2.append(rfCO2)
    trfCH4 = []
    for t in range(measd):
        rfCH4 = mbCH4 * reCH4 * f1f2 * math.exp(-(t/12.4))
        t = t + 1
        trfCH4.append(rfCH4)
    trfN2O = []
    for t in range(measd):
        rfN2O = mbN2O * reN2O * math.exp(-(t/121.0))
        t = t + 1
        trfN2O.append(rfN2O)
    radf={'CO2': trfCO2, 'CH4': trfCH4, 'N2O': trfN2O}
    return(radf)

# %%
# time span for calculation of the radiative forcing
measd = 112

# %%
prospRF(measd)
# Out:
# {'CO2': [1.7577236999999998e-15,
#   1.6426369927147825e-15,
#   1.5487899761517869e-15,
#   1.471844883645099e-15,
#   1.4083615136831596e-15,
#   1.3556111897384365e-15,
#   1.3114292895963302e-15,
#   1.2740983477956326e-15,
#   1.2422553926431625e-15,
#   1.2148184934017177e-15,
#   1.19092853493362e-15,
#   1.169903062798319e-15,
#   1.151199696327095e-15,
#   1.134387126023187e-15,
#   1.1191221228954997e-15,
#   1.1051313133294605e-15,
#   1.092196731507004e-15,
#   1.080144366221573e-15,
#   1.0688350813007667e-15,
#   1.0581574175533158e-15,
#   1.0480218861775935e-15,
#   1.038356444437978e-15,
#   1.029102908518342e-15,
#   1.0202141092747648e-15,
#   1.0116516368876212e-15,
#   1.003384052340647e-15,
#   9.953854689626645e-16,
#   9.876344273287624e-16,
#   9.801130027196776e-16,
#   9.728060969432218e-16,
#   9.6570087631335e-16,
#   9.587863255026985e-16,
#   9.520528932626098e-16,
#   9.454922109812149e-16,
#   9.39096868994979e-16,
#   9.328602386960696e-16,
#   9.267763309565989e-16,
#   9.208396833555864e-16,
#   9.150452702519507e-16,
#   9.093884309814122e-16,
#   9.038648124338076e-16,
#   8.984703230430626e-16,
#   8.932010958369885e-16,
#   8.880534586815091e-16,
#   8.830239102403247e-16,
#   8.781091004773015e-16,
#   2.7797805949024784e-13,
#   2.7569018719541307e-13,
#   2.734211450184916e-13,
#   2.711707779799673e-13,
#   2.689389323758688e-13,
#   2.6672545576727066e-13,
#   2.645301969698816e-13,
#   2.623530060437186e-13,
#   2.6019373428286555e-13,
#   2.580522342053163e-13,
#   2.559283595429016e-13,
#   2.5382196523129863e-13,
#   2.5173290740012274e-13,
#   2.49661043363101e-13,
#   2.4760623160832646e-13,
#   2.455683317885927e-13,
#   2.435472047118077e-13,
#   2.4154271233148684e-13,
#   2.3955471773732416e-13,
#   2.375830851458412e-13,
#   2.3562767989111245e-13,
#   2.3368836841556786e-13,
#   2.317650182608702e-13,
#   2.2985749805886844e-13,
#   2.279656775226244e-13,
#   2.2608942743751466e-13,
#   2.2422861965240425e-13,
#   2.223831270708944e-13,
#   2.2055282364264106e-13,
#   2.1873758435474584e-13,
#   2.1693728522321728e-13,
#   2.151518032845024e-13,
#   2.133810165870882e-13,
#   2.1162480418317224e-13,
#   2.0988304612040148e-13,
#   2.0815562343367963e-13,
#   2.064424181370412e-13,
#   2.0474331321559328e-13,
#   2.03058192617523e-13,
#   2.0138694124617105e-13,
#   1.9972944495217023e-13,
#   1.9808559052564914e-13,
#   1.9645526568849951e-13,
#   1.9483835908670753e-13,
#   1.9323476028274807e-13,
#   1.9164435974804172e-13,
#   1.9006704885547373e-13,
#   1.8850271987197463e-13,
#   1.8695126595116185e-13,
#   1.8541258112604185e-13,
#   1.8388656030177267e-13,
#   1.8237309924848532e-13,
#   1.8087209459416517e-13,
#   1.7938344381759107e-13,
#   1.779070452413333e-13,
#   1.7644279802480852e-13,
#   1.7499060215739247e-13,
#   1.7355035845158882e-13,
#   1.721219685362547e-13,
#   1.7070533484988159e-13,
#   1.693003606339319e-13,
#   1.6790694992623001e-13,
#   1.6652500755440806e-13,
#   1.6515443912940532e-13,
#   1.637951510390214e-13,
#   1.6244705044152226e-13,
#   1.611100452592992e-13,
#   1.5978404417257947e-13,
#   1.5846895661318912e-13,
#   1.5716469275836715e-13,
#   1.558711635246303e-13,
#   1.5458828056168856e-13,
#   1.533159562464106e-13,
#   1.5205410367683914e-13,
#   1.508026366662553e-13,
#   1.4956146973729177e-13,
#   1.483305181160948e-13,
#   1.4710969772653381e-13]}

# %% [markdown]
# # Import inventory

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
link = "THG_bustransBsum_alle.xlsx"
df=pd.read_excel(link)

# %%
df
# Out:
#     Unnamed: 0  year process        CO2       CH4       N2O  Unnamed: 6  \
# 0            0  2024     Sum  13.155745  0.042602  0.000741         NaN
# 1            1  2025     Sum  13.670809  0.044466  0.000819         NaN
# 2            2  2026     Sum  12.610881  0.040937  0.000809         NaN
# 3            3  2027     Sum  11.527862  0.037336  0.000789         NaN
# 4            4  2028     Sum  10.444612  0.033761  0.000759         NaN
# 5            5  2029     Sum   9.577963  0.031045  0.000725         NaN
# 6            6  2030     Sum   8.689423  0.028405  0.000679         NaN
# 7            7  2031     Sum   7.601680  0.024867  0.000613         NaN
# 8            8  2032     Sum   6.513746  0.021360  0.000538         NaN
# 9            9  2033     Sum   7.026240  0.023916  0.000544         NaN
# 10          10  2034     Sum   6.304559  0.021849  0.000455         NaN
# 11          11  2035     Sum   5.154077  0.018209  0.000352         NaN
# 12          12  2036     Sum   4.039133  0.014712  0.000240         NaN
# 13          13  2037     Sum   0.940786  0.003855  0.000018         NaN
# 14          14  2038     Sum   0.389370  0.001613  0.000010         NaN
# 15          15  2039     Sum   0.387066  0.001603  0.000010         NaN
# 16          16  2040     Sum   0.384765  0.001593  0.000010         NaN
# 17          17  2041     Sum   0.383787  0.001589  0.000010         NaN
# 18          18  2042     Sum   0.438890  0.001846  0.000011         NaN
# 19          19  2043     Sum   0.437538  0.001841  0.000011         NaN
# 20          20  2044     Sum   0.436192  0.001836  0.000011         NaN
# 21          21  2045     Sum   0.434852  0.001832  0.000011         NaN
# 22          22  2046     Sum   0.434233  0.001829  0.000012         NaN
# 23          23  2047     Sum   0.433618  0.001827  0.000012         NaN
# 24          24  2048     Sum   0.433007  0.001824  0.000012         NaN
# 25          25  2049     Sum   0.432399  0.001822  0.000012         NaN
# 26          26  2050     Sum   0.377388  0.001564  0.000010         NaN
# 27          27  2051     Sum   0.377388  0.001564  0.000010         NaN
# 28          28  2052     Sum   0.377388  0.001564  0.000010         NaN
# 29          29  2053     Sum   0.377388  0.001564  0.000010         NaN
# 30          30  2054     Sum   0.431794  0.001819  0.000012         NaN
#
#     Unnamed: 7  Unnamed: 8 Unnamed: 9  ...  Unnamed: 17  Unnamed: 18  \
# 0            0        2024        Sum  ...     0.000000     0.000000
# 1            1        2025        Sum  ...     0.527773     0.002040
# 2            2        2026        Sum  ...     0.508803     0.001963
# 3            3        2027        Sum  ...     0.490320     0.001889
# 4            4        2028        Sum  ...     0.472303     0.001816
# 5            5        2029        Sum  ...     0.671474     0.002579
# 6            6        2030        Sum  ...     0.646162     0.002478
# 7            7        2031        Sum  ...     0.627843     0.002397
# 8            8        2032        Sum  ...     0.609962     0.002319
# 9            9        2033        Sum  ...     2.193065     0.008274
# 10          10        2034        Sum  ...     2.126813     0.008006
# 11          11        2035        Sum  ...     2.061966     0.007745
# 12          12        2036        Sum  ...     2.022735     0.007572
# 13          13        2037        Sum  ...     0.000000     0.000000
# 14          14        2038        Sum  ...     0.000000     0.000000
# 15          15        2039        Sum  ...     0.000000     0.000000
# 16          16        2040        Sum  ...     0.000000     0.000000
# 17          17        2041        Sum  ...     0.000000     0.000000
# 18          18        2042        Sum  ...     0.000000     0.000000
# 19          19        2043        Sum  ...     0.000000     0.000000
# 20          20        2044        Sum  ...     0.000000     0.000000
# 21          21        2045        Sum  ...     0.000000     0.000000
# 22          22        2046        Sum  ...     0.000000     0.000000
# 23          23        2047        Sum  ...     0.000000     0.000000
# 24          24        2048        Sum  ...     0.000000     0.000000
# 25          25        2049        Sum  ...     0.000000     0.000000
# 26          26        2050        Sum  ...     0.000000     0.000000
# 27          27        2051        Sum  ...     0.000000     0.000000
# 28          28        2052        Sum  ...     0.000000     0.000000
# 29          29        2053        Sum  ...     0.000000     0.000000
# 30          30        2054        Sum  ...     0.000000     0.000000
#
#     Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22 Unnamed: 23  \
# 0      0.000000          NaN            0         2024         Sum
# 1      0.000014          NaN            1         2025         Sum
# 2      0.000014          NaN            2         2026         Sum
# 3      0.000014          NaN            3         2027         Sum
# 4      0.000013          NaN            4         2028         Sum
# 5      0.000019          NaN            5         2029         Sum
# 6      0.000019          NaN            6         2030         Sum
# 7      0.000018          NaN            7         2031         Sum
# 8      0.000018          NaN            8         2032         Sum
# 9      0.000107          NaN            9         2033         Sum
# 10     0.000106          NaN           10         2034         Sum
# 11     0.000105          NaN           11         2035         Sum
# 12     0.000104          NaN           12         2036         Sum
# 13     0.000000          NaN           13         2037         Sum
# 14     0.000000          NaN           14         2038         Sum
# 15     0.000000          NaN           15         2039         Sum
# 16     0.000000          NaN           16         2040         Sum
# 17     0.000000          NaN           17         2041         Sum
# 18     0.000000          NaN           18         2042         Sum
# 19     0.000000          NaN           19         2043         Sum
# 20     0.000000          NaN           20         2044         Sum
# 21     0.000000          NaN           21         2045         Sum
# 22     0.000000          NaN           22         2046         Sum
# 23     0.000000          NaN           23         2047         Sum
# 24     0.000000          NaN           24         2048         Sum
# 25     0.000000          NaN           25         2049         Sum
# 26     0.000000          NaN           26         2050         Sum
# 27     0.000000          NaN           27         2051         Sum
# 28     0.000000          NaN           28         2052         Sum
# 29     0.000000          NaN           29         2053         Sum
# 30     0.000000          NaN           30         2054         Sum
#
#     Unnamed: 24  Unnamed: 25  Unnamed: 26
# 0      0.440332     0.001792     0.000010
# 1      0.430661     0.001761     0.000010
# 2      0.446408     0.001835     0.000010
# 3      0.439423     0.001810     0.000010
# 4      0.432478     0.001785     0.000010
# 5      0.425573     0.001760     0.000010
# 6      0.621781     0.002649     0.000015
# 7      0.610843     0.002605     0.000015
# 8      0.599975     0.002562     0.000015
# 9      0.589176     0.002519     0.000015
# 10     0.994106     0.004045     0.000019
# 11     0.969307     0.003962     0.000018
# 12     0.955048     0.003908     0.000018
# 13     0.940786     0.003855     0.000018
# 14     0.389370     0.001613     0.000010
# 15     0.387066     0.001603     0.000010
# 16     0.384765     0.001593     0.000010
# 17     0.383787     0.001589     0.000010
# 18     0.438890     0.001846     0.000011
# 19     0.437538     0.001841     0.000011
# 20     0.436192     0.001836     0.000011
# 21     0.434852     0.001832     0.000011
# 22     0.434233     0.001829     0.000012
# 23     0.433618     0.001827     0.000012
# 24     0.433007     0.001824     0.000012
# 25     0.432399     0.001822     0.000012
# 26     0.377388     0.001564     0.000010
# 27     0.377388     0.001564     0.000010
# 28     0.377388     0.001564     0.000010
# 29     0.377388     0.001564     0.000010
# 30     0.431794     0.001819     0.000012
#
# [31 rows x 27 columns]

# %% [markdown]
# # dLCIA

# %%
#ensures, that values exist for the whole time span

def add_missing_years(df, years_range):
    missing_years = [year for year in years_range if year not in df['year'].values]
    missing_data = pd.DataFrame({'year': missing_years, 'process': df['process'][ultimo], 'CO2': df['CO2'][ultimo], 'CH4': df['CH4'][ultimo], 'N2O': df['N2O'][ultimo]})
    df = pd.concat([df, missing_data], ignore_index=True)
    return df

# %%
ultimo = df.index[-1]
print(df['CO2'][ultimo])
# Out:
# 0.4317941257196485

# %%
years_range = range(2024, 2101)

# %%
#df = pd.DataFrame({'year': [2024, 2025, 2027], 'value': [1, 2, 3]})
df = add_missing_years(df, years_range)

# %%
df
# Out:
#     Unnamed: 0  year process        CO2       CH4       N2O  Unnamed: 6  \
# 0          0.0  2024     Sum  13.155745  0.042602  0.000741         NaN
# 1          1.0  2025     Sum  13.670809  0.044466  0.000819         NaN
# 2          2.0  2026     Sum  12.610881  0.040937  0.000809         NaN
# 3          3.0  2027     Sum  11.527862  0.037336  0.000789         NaN
# 4          4.0  2028     Sum  10.444612  0.033761  0.000759         NaN
# ..         ...   ...     ...        ...       ...       ...         ...
# 72         NaN  2096     Sum   0.431794  0.001819  0.000012         NaN
# 73         NaN  2097     Sum   0.431794  0.001819  0.000012         NaN
# 74         NaN  2098     Sum   0.431794  0.001819  0.000012         NaN
# 75         NaN  2099     Sum   0.431794  0.001819  0.000012         NaN
# 76         NaN  2100     Sum   0.431794  0.001819  0.000012         NaN
#
#     Unnamed: 7  Unnamed: 8 Unnamed: 9  ...  Unnamed: 17  Unnamed: 18  \
# 0          0.0      2024.0        Sum  ...     0.000000     0.000000
# 1          1.0      2025.0        Sum  ...     0.527773     0.002040
# 2          2.0      2026.0        Sum  ...     0.508803     0.001963
# 3          3.0      2027.0        Sum  ...     0.490320     0.001889
# 4          4.0      2028.0        Sum  ...     0.472303     0.001816
# ..         ...         ...        ...  ...          ...          ...
# 72         NaN         NaN        NaN  ...          NaN          NaN
# 73         NaN         NaN        NaN  ...          NaN          NaN
# 74         NaN         NaN        NaN  ...          NaN          NaN
# 75         NaN         NaN        NaN  ...          NaN          NaN
# 76         NaN         NaN        NaN  ...          NaN          NaN
#
#     Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22 Unnamed: 23  \
# 0      0.000000          NaN          0.0       2024.0         Sum
# 1      0.000014          NaN          1.0       2025.0         Sum
# 2      0.000014          NaN          2.0       2026.0         Sum
# 3      0.000014          NaN          3.0       2027.0         Sum
# 4      0.000013          NaN          4.0       2028.0         Sum
# ..          ...          ...          ...          ...         ...
# 72          NaN          NaN          NaN          NaN         NaN
# 73          NaN          NaN          NaN          NaN         NaN
# 74          NaN          NaN          NaN          NaN         NaN
# 75          NaN          NaN          NaN          NaN         NaN
# 76          NaN          NaN          NaN          NaN         NaN
#
#     Unnamed: 24  Unnamed: 25  Unnamed: 26
# 0      0.440332     0.001792      0.00001
# 1      0.430661     0.001761      0.00001
# 2      0.446408     0.001835      0.00001
# 3      0.439423     0.001810      0.00001
# 4      0.432478     0.001785      0.00001
# ..          ...          ...          ...
# 72          NaN          NaN          NaN
# 73          NaN          NaN          NaN
# 74          NaN          NaN          NaN
# 75          NaN          NaN          NaN
# 76          NaN          NaN          NaN
#
# [77 rows x 27 columns]

# %%
df['CO2'].plot()
# Out:
# <Axes: >

# %%
df['CH4'].plot()
# Out:
# <Axes: >

# %%
df['N2O'].plot()
# Out:
# <Axes: >

# %%
tem = []
for t in range(measd):
    tem.append(t)

fig, ax = plt.subplots()
#ax.plot(tCO2, valores, 'r--', label = "CED, gesamt")
c = 0
ax.plot(tem, prospRF(measd)['CO2'], label = '$CO_2$')
ax.plot(tem, prospRF(measd)['CH4'], label = '$CH_4$')
ax.plot(tem, prospRF(measd)['N2O'], label = '$N_2O$')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.ylabel('radiative forcing [W/m²]')
plt.xlabel('time [a]')

#plt.ylim(bottom=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.head()
# Out:
#    Unnamed: 0  year process        CO2       CH4       N2O  Unnamed: 6  \
# 0         0.0  2024     Sum  13.155745  0.042602  0.000741         NaN
# 1         1.0  2025     Sum  13.670809  0.044466  0.000819         NaN
# 2         2.0  2026     Sum  12.610881  0.040937  0.000809         NaN
# 3         3.0  2027     Sum  11.527862  0.037336  0.000789         NaN
# 4         4.0  2028     Sum  10.444612  0.033761  0.000759         NaN
#
#    Unnamed: 7  Unnamed: 8 Unnamed: 9  ...  Unnamed: 17  Unnamed: 18  \
# 0         0.0      2024.0        Sum  ...     0.000000     0.000000
# 1         1.0      2025.0        Sum  ...     0.527773     0.002040
# 2         2.0      2026.0        Sum  ...     0.508803     0.001963
# 3         3.0      2027.0        Sum  ...     0.490320     0.001889
# 4         4.0      2028.0        Sum  ...     0.472303     0.001816
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22 Unnamed: 23  \
# 0     0.000000          NaN          0.0       2024.0         Sum
# 1     0.000014          NaN          1.0       2025.0         Sum
# 2     0.000014          NaN          2.0       2026.0         Sum
# 3     0.000014          NaN          3.0       2027.0         Sum
# 4     0.000013          NaN          4.0       2028.0         Sum
#
#    Unnamed: 24  Unnamed: 25  Unnamed: 26
# 0     0.440332     0.001792      0.00001
# 1     0.430661     0.001761      0.00001
# 2     0.446408     0.001835      0.00001
# 3     0.439423     0.001810      0.00001
# 4     0.432478     0.001785      0.00001
#
# [5 rows x 27 columns]

# %%
pro = []
for em in df['process']:
    if em not in pro:
        pro.append(em)
        
print(pro)
# Out:
# ['Sum']

# %%
def convolvo(pro, df, radf, t0):
    radiat = {}
    for p in pro:
        e = 0
        print(p)
        for em in df:
            print('em', em)
            t = 0
            for ga in radf:
                if ga==em:
                    print('ga', ga)
                    cumrf = [0]
                    tempo = [t0]
                    z = 0
                    for m in df['process']:
                        if m == p:
                            zw = 0
                            for tau in range(t+1):
                                try:
                                    zw = zw + df[em][z-t+tau] * radf[ga][t-tau]
                                except:
                                    raise IndexError('calculated range of impulse response function too short! Change measd.')
                            #    print(z, t, tau)
                            cumrf.append(zw)
                            tempo.append(df['year'][z])
                            t = t+1
                        z = z+1
                    print(cumrf)
                    print(tempo)
                    radiat[p,ga]=cumrf
            e = e+1
    return(tempo, radiat)

# %%
(tempo, radiat) = convolvo(pro, df, prospRF(measd), 2023)

# %%
print(radiat)
# Out:
-15, 7.460742164766974e-15, 7.267181129976665e-15, 7.0886170145634635e-15, 6.923887871903935e-15, 6.7719217818608624e-15, 6.631729875619296e-15, 6.502399900951433e-15, 6.38309028603851e-15, 6.273024663221937e-15, 6.171486817048837e-15, 6.077816023738069e-15, 5.9914027517398586e-15, 5.911684695411853e-15, 5.8381431160020775e-15, 5.770299466128937e-15, 5.707712275793216e-15, 5.6499742796588025e-15, 5.5967097669089024e-15, 5.547572136432785e-15, 5.502241641434276e-15, 5.460423308785763e-15, 5.421845019588631e-15, 5.386255738449979e-15, 5.3534238799532555e-15, 5.323135801693133e-15, 5.295194414068586e-15, 5.2694178977878186e-15, 5.245638520739667e-15, 5.223701546532641e-15, 5.2034642275992955e-15], ('Sum', 'N2O'): [0, 2.728616724994821e-16, 5.719884712022833e-16, 8.652961375849609e-16, 1.1488360636218879e-15, 1.418888034235169e-15, 1.6740366862456834e-15, 1.9101349392392305e-15, 2.1200689429534e-15, 2.3007738143067496e-15, 2.482138490234676e-15, 2.6291979506971043e-15, 2.7372796947985713e-15, 2.803025503476059e-15, 2.7865602 ...

# %% [markdown]
# # Plots

# %%
fig, ax = plt.subplots()
#c = 0
#res = {}
for cap in radiat.keys():
    ax.plot(tempo, radiat[cap], label = cap)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.ylabel('rad. forc. [W/m²]')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np

# %%
colors = ['darkblue', 'orange', 'green']  
#y = np.arange(0, 2.5e-6)
fig, ax = plt.subplots()
ax.stackplot(tempo, [radiat[cap] for cap in radiat], colors=colors)
plt.ylabel('radiative forcing [W/m²]')
plt.xlabel('time [a]')
#plt.ylim(0, 1.5e-11)
plt.xlim(2021,2100)
#plt.ylim(0, 0.00022)
plt.show()

# %%
radiat
# Out:
# {('Sum', 'CO2'): [0,
#   2.3124164070640473e-14,
#   4.563961762529724e-14,
#   6.499810670452129e-14,
#   8.151432272623258e-14,
#   9.547579558732832e-14,
#   1.0749513285439881e-13,
#   1.1769626664772104e-13,
#   1.2586318269050318e-13,
#   1.3212764950223568e-13,
#   1.3941082092121757e-13,
#   1.454480331529364e-13,
#   1.495509984892803e-13,
#   1.5188559704586733e-13,
#   1.4904671533960434e-13,
#   1.4580685236343476e-13,
#   1.4308068623790485e-13,
#   1.4076632894871408e-13,
#   1.3878520104364477e-13,
#   1.371714664102063e-13,
#   1.3576824905337212e-13,
#   1.3453608968486379e-13,
#   1.3344359201582205e-13,
#   1.324670139461718e-13,
#   1.315863399442831e-13,
#   1.3078559342378115e-13,
#   1.3005200241428253e-13,
#   1.2927970736584657e-13,
#   1.2856344738177612e-13,
#   1.278953847050889e-13,
#   1.2726920409098223e-13,
#   1.2677543059261762e-13,
#   1.2630802804175909e-13,
#   1.2586477271571884e-13,
#   1.2544381367869193e-13,
#   1.2504359787774833e-13,
#   1.2466281070393563e-13,
#   1.243003288139265e-13,
#   1.2395518267198212e-13,
#   1.236265267986134e-13,
#   1.2331361612974935e-13,
#   1.2301578722110728e-13,
#   1.2273244329475107e-13,
#   1.2246304233272816e-13,
#   1.2220708758748563e-13,
#   1.2196412000940166e-13,
#   1.2173371219532536e-13,
#   1.2151546354410267e-13,
#   1.2130899637013636e-13,
#   1.211139527776073e-13,
#   1.2092999213886898e-13,
#   1.2075678905294072e-13,
#   1.2059403168571564e-13,
#   1.2044142041386494e-13,
#   1.2029866671056685e-13,
#   1.2016549222398526e-13,
#   1.2004162800956884e-13,
#   1.1992681388528567e-13,
#   1.1982079788528365e-13,
#   1.1972333579252178e-13,
#   1.196341907349258e-13,
#   1.195531328327999e-13,
#   1.1947993888774224e-13,
#   1.1941439210531531e-13,
#   1.1935628184530007e-13,
#   1.1930540339462488e-13,
#   1.192615577590523e-13,
#   1.1922455147050019e-13,
#   1.1919419640749909e-13,
#   1.1917030962678677e-13,
#   1.1915271320443444e-13,
#   1.1914123408521455e-13,
#   1.1913570393916742e-13,
#   1.191359590245234e-13,
#   1.1914184005629436e-13,
#   1.1915319207997283e-13,
#   1.1916986434987716e-13,
#   1.1919171021176248e-13],
#  ('Sum', 'CH4'): [0,
#   9.002809600527043e-15,
#   1.7702180921381887e-14,
#   2.4981743736316136e-14,
#   3.09361512628194e-14,
#   3.5673720700982356e-14,
#   3.947031897928508e-14,
#   4.241481558101972e-14,
#   4.438351246534213e-14,
#   4.545866075262789e-14,
#   4.6990699914294993e-14,
#   4.7967126524146054e-14,
#   4.809864270101871e-14,
#   4.748098031081707e-14,
#   4.46169327680327e-14,
#   4.1500945935404346e-14,
#   3.862420373211234e-14,
#   3.596817808991675e-14,
#   3.351715092973613e-14,
#   3.131041076178916e-14,
#   2.927361288279655e-14,
#   2.7393596718713617e-14,
#   2.5658221272142522e-14,
#   2.405678254676769e-14,
#   2.2578906167045593e-14,
#   2.1215021507537967e-14,
#   1.995629943667987e-14,
#   1.874058529691352e-14,
#   1.7619063497870274e-14,
#   1.6584436109254938e-14,
#   1.5629970637263064e-14,
#   1.4803465782411455e-14,
#   1.4040997714129131e-14,
#   1.3337604924918535e-14,
#   1.2688710320023069e-14,
#   1.2090091433504497e-14,
#   1.153785295194945e-14,
#   1.102840136701225e-14,
#   1.0558421591853918e-14,
#   1.0124855389316519e-14,
#   9.7248814714615e-15,
#   9.355897140976253e-15,
#   9.015501354986538e-15,
#   8.701479101068113e-15,
#   8.41178698378971e-15,
#   8.144539927996507e-15,
#   7.897998912310203e-15,
#   7.670559653025454e-15,
#   7.460742164766974e-15,
#   7.267181129976665e-15,
#   7.0886170145634635e-15,
#   6.923887871903935e-15,
#   6.7719217818608624e-15,
#   6.631729875619296e-15,
#   6.502399900951433e-15,
#   6.38309028603851e-15,
#   6.273024663221937e-15,
#   6.171486817048837e-15,
#   6.077816023738069e-15,
#   5.9914027517398586e-15,
#   5.911684695411853e-15,
#   5.8381431160020775e-15,
#   5.770299466128937e-15,
#   5.707712275793216e-15,
#   5.6499742796588025e-15,
#   5.5967097669089024e-15,
#   5.547572136432785e-15,
#   5.502241641434276e-15,
#   5.460423308785763e-15,
#   5.421845019588631e-15,
#   5.386255738449979e-15,
#   5.3534238799532555e-15,
#   5.323135801693133e-15,
#   5.295194414068586e-15,
#   5.2694178977878186e-15,
#   5.245638520739667e-15,
#   5.223701546532641e-15,
#   5.2034642275992955e-15],
#  ('Sum', 'N2O'): [0,
#   2.728616724994821e-16,
#   5.719884712022833e-16,
#   8.652961375849609e-16,
#   1.1488360636218879e-15,
#   1.418888034235169e-15,
#   1.6740366862456834e-15,
#   1.9101349392392305e-15,
#   2.1200689429534e-15,
#   2.3007738143067496e-15,
#   2.482138490234676e-15,
#   2.6291979506971043e-15,
#   2.7372796947985713e-15,
#   2.803025503476059e-15,
#   2.7865602966626218e-15,
#   2.7672513483747776e-15,
#   2.7481036005262183e-15,
#   2.7291155781088445e-15,
#   2.710291298036793e-15,
#   2.6922017022703377e-15,
#   2.674265884495377e-15,
#   2.656482459639822e-15,
#   2.638850053146768e-15,
#   2.6213951930623316e-15,
#   2.6041162843400434e-15,
#   2.5870117443174865e-15,
#   2.570080002694904e-15,
#   2.5527528790892098e-15,
#   2.535568364745984e-15,
#   2.5185252859330966e-15,
#   2.501622478578704e-15,
#   2.4854254102613195e-15,
#   2.469361650392556e-15,
#   2.4534301017897523e-15,
#   2.4376296763005104e-15,
#   2.4219592947283665e-15,
#   2.4064178867590815e-15,
#   2.39100439088754e-15,
#   2.375717754345239e-15,
#   2.360556933028395e-15,
#   2.345520891426616e-15,
#   2.3306086025521848e-15,
#   2.315819047869909e-15,
#   2.3011512172275536e-15,
#   2.2866041087868477e-15,
#   2.2721767289550563e-15,
#   2.2578680923171145e-15,
#   2.243677221568327e-15,
#   2.2296031474476074e-15,
#   2.215644908671287e-15,
#   2.2018015518674485e-15,
#   2.1880721315108147e-15,
#   2.1744557098581626e-15,
#   2.1609513568842817e-15,
#   2.147558150218439e-15,
#   2.1342751750813956e-15,
#   2.1211015242229107e-15,
#   2.1080362978597846e-15,
#   2.095078603614396e-15,
#   2.0822275564537574e-15,
#   2.0694822786290606e-15,
#   2.056841899615725e-15,
#   2.044305556053943e-15,
#   2.0318723916897045e-15,
#   2.019541557316325e-15,
#   2.007312210716428e-15,
#   1.9951835166044334e-15,
#   1.983154646569499e-15,
#   1.9712247790189383e-15,
#   1.959393099122108e-15,
#   1.947658798754752e-15,
#   1.9360210764438056e-15,
#   1.924479137312649e-15,
#   1.9130321930268244e-15,
#   1.901679461740185e-15,
#   1.8904201680414935e-15,
#   1.8792535429014644e-15,
#   1.868178823620234e-15]}

# %%
n = 0
for i in list(radiat.values())[0]:
    sum(list(radiat[cap][n] for cap in radiat))
    n+=1

# %%
[sum(radiat[cap][n] for cap in radiat) for n in range(len(list(radiat.values())[0]))]
# Out:
# [0,
#  3.2399835343667e-14,
#  6.391378701788142e-14,
#  9.084514657842239e-14,
#  1.1359931005267388e-13,
#  1.3256840432254586e-13,
#  1.486394885199296e-13,
#  1.6202121716798e-13,
#  1.723667640987987e-13,
#  1.798870840691703e-13,
#  1.8888365932574725e-13,
#  1.9604435762777956e-13,
#  2.0038692088509759e-13,
#  2.0216960286016045e-13,
#  1.9645020840429964e-13,
#  1.9007504964721388e-13,
#  1.844529935705434e-13,
#  1.7946362261673968e-13,
#  1.750126432714177e-13,
#  1.711740788742658e-13,
#  1.6771612782066403e-13,
#  1.645861688632172e-13,
#  1.6174066334111135e-13,
#  1.5914519168600182e-13,
#  1.5676936239566875e-13,
#  1.545876266756366e-13,
#  1.5257838185365728e-13,
#  1.505730455418493e-13,
#  1.4871807924439236e-13,
#  1.4699834610027693e-13,
#  1.45400797206824e-13,
#  1.440643217852904e-13,
#  1.4281838740628077e-13,
#  1.4165580774242712e-13,
#  1.405701536750155e-13,
#  1.395556486059812e-13,
#  1.3860708154264418e-13,
#  1.377197345718263e-13,
#  1.3688932201818128e-13,
#  1.3611193912095833e-13,
#  1.3538401849263747e-13,
#  1.3470229296463571e-13,
#  1.3406376369760752e-13,
#  1.3346567265102384e-13,
#  1.3290547868006217e-13,
#  1.3238083666635322e-13,
#  1.3188957919995267e-13,
#  1.3142970041869645e-13,
#  1.3099934168235093e-13,
#  1.3059677881625526e-13,
#  1.302204107052999e-13,
#  1.2986874905635546e-13,
#  1.2954040917743465e-13,
#  1.2923410164636853e-13,
#  1.2894862476173673e-13,
#  1.2868285768510517e-13,
#  1.2843575419701368e-13,
#  1.282063370001943e-13,
#  1.2799369251263613e-13,
#  1.277969661007154e-13,
#  1.2761535770896673e-13,
#  1.274481178484177e-13,
#  1.2729454390992513e-13,
#  1.2715397677279822e-13,
#  1.270257976822752e-13,
#  1.269094253722502e-13,
#  1.2680431341208953e-13,
#  1.2670994775850396e-13,
#  1.266258444953038e-13,
#  1.265515477454975e-13,
#  1.2648662774163917e-13,
#  1.264306790416116e-13,
#  1.263833188781732e-13,
#  1.2634418563161878e-13,
#  1.2631293741582236e-13,
#  1.26289250768754e-13,
#  1.2627281943931127e-13,
#  1.2626335326298202e-13]

# %%
fig, ax = plt.subplots()
#c = 0
#res = {}
ax = ax.twinx()
ax.plot(tempo, [sum(radiat[cap][n] for cap in radiat) for n in range(len(list(radiat.values())[0]))], 'k--', label = cap)
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.ylabel('rad. forc. [W/m²]')
plt.xlim(2023, 2055)
plt.ylim(0, 2.5e-13)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Save as excel

# %%
dfrf = pd.DataFrame(radiat, index = tempo)
dfrf
# Out:
#                Sum
#                CO2           CH4           N2O
# 2023  0.000000e+00  0.000000e+00  0.000000e+00
# 2024  2.312416e-14  9.002810e-15  2.728617e-16
# 2025  4.563962e-14  1.770218e-14  5.719885e-16
# 2026  6.499811e-14  2.498174e-14  8.652961e-16
# 2027  8.151432e-14  3.093615e-14  1.148836e-15
# ...            ...           ...           ...
# 2096  1.191360e-13  5.295194e-15  1.913032e-15
# 2097  1.191418e-13  5.269418e-15  1.901679e-15
# 2098  1.191532e-13  5.245639e-15  1.890420e-15
# 2099  1.191699e-13  5.223702e-15  1.879254e-15
# 2100  1.191917e-13  5.203464e-15  1.868179e-15
#
# [78 rows x 3 columns]

# %%
dfrf.to_excel("Radforc_" + link)
